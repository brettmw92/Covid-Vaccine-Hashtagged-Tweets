# %%
# Count words from twitter data
# SOURCE: https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/calculate-tweet-word-frequencies-in-python/
import pandas as pd 
import numpy as np
import itertools
import collections
import nltk
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
#read the CSV file
data_file = pd.read_csv('covidvaccinetweets.csv')
data_file.head(10)
# Out:
# C:\Users\AFanch\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (5,7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    INDEX                                    USER_NAME  \
# 0      1                                     MyNewsNE
# 1      2                                Shubham Gupta
# 2      3                      Journal of Infectiology
# 3      4                                         Zane
# 4      5                           Ann-Maree O’Connor
# 5      6                 Raunak Scherbatsky DankWorth
# 6      7                             Rajesh Tadepalli
# 7      8  AKisASocialisolationist wash yer damn hands
# 8      9                           Dr. Joseph Santoro
# 9     10                                     VUMC OAP
#
#                  USER_LOCATION  \
# 0                        Assam
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4    Adelaide, South Australia
# 5                          NaN
# 6             Hyderabad, India
# 7  The Great Pacific Northwest
# 8         Washington, DC 20009
# 9                Nashville, TN
#
#                                     USER_DESCRIPTION  USER_FOLLOWERS  \
# 0  MyNewsNE a dedicated multi-lingual media house...              64
# 1  I will tell about all experiences of my life f...               1
# 2  Journal of Infectiology (ISSN 2689-9981) is ac...             143
# 3                                  Fresher than you.              29
# 4  Retired university administrator. Melburnian b...              83
# 5  Neuro surgeon + Diagnostician.👨‍⚕️\na good phy...               3
# 6  Growth Initiatives @tech_mahindra | AIMer | Br...             918
# 7  Iconoclast, cat person, soccer fan, textile & ...            2321
# 8  Neuro PhD, #Innovator, #Technologist, #Startup...           19091
# 9  Office of Advanced Practice, Vanderbilt Univer...             282
#
#   USER_FRIENDS  USER_FAVOURITES USER_VERIFIED   DATE  \
# 0           11            110.0         FALSE  44061
# 1           17              0.0         FALSE  44061
# 2          566              8.0         FALSE  44061
# 3           25            620.0         FALSE  44061
# 4          497          10737.0         FALSE  44061
# 5           27            918.0         FALSE  44061
# 6         2561          31837.0         FALSE  44061
# 7         3236         264351.0         FALSE  44061
# 8        20986         128119.0         FALSE  44061
# 9           96            788.0         FALSE  44061
#
#                                                 TEXT  ...  \
# 0  Australia to Manufacture Covid-19 Vaccine and ...  ...
# 1  #CoronavirusVaccine #CoronaVaccine #CovidVacci...  ...
# 2  Deaths due to COVID-19 in Affected Countries\n...  ...
# 3  @Team_Subhashree @subhashreesotwe @iamrajchoco...  ...
# 4  @michellegrattan @ConversationEDU This is what...  ...
# 5  The Multi-system Inflammatory Syndrome-Childre...  ...
# 6  @PrivilRodrigues @yatish57 @deepkaranahuja @sh...  ...
# 7  @MSNBC Well, let’s qualify that: would anyone ...  ...
# 8  Most countries, without the ability to make #V...  ...
# 9  #DNA  zooms up charts in 1st week; hear #vacci...  ...
#
#                 SOURCE IS_RETWEET        COUNTRY SUBJECTIVITY  POLARITY  \
# 0      Twitter Web App      False     Antarctica     0.800000  0.400000
# 1  Twitter for Android      False     Antarctica     0.780000  0.910000
# 2      Twitter Web App      False     Antarctica     0.437500  0.187500
# 3  Twitter for Android      False     Antarctica     0.500000  0.500000
# 4      Twitter Web App      False      Australia     0.000000  0.000000
# 5  Twitter for Android      False     Antarctica     0.200000  0.000000
# 6  Twitter for Android      False          India     0.000000  0.000000
# 7   Twitter for iPhone      False  United States     0.600000 -0.100000
# 8       Hootsuite Inc.      False  United States     0.233333  0.066667
# 9      Twitter Web App      False  United States     0.000000  0.000000
#
#       SCORE  VACCINE_BRAND                                       TEXT_CLEANED  \
# 0  Positive  Not Mentioned  Australia  Manufacture Covid19 Vaccine  give i...
# 1  Positive  Not Mentioned  CoronavirusVaccine CoronaVaccine CovidVaccine ...
# 2  Positive  Not Mentioned  Deaths due  COVID19 in Affected Countries\nRea...
# 3  Positive  Not Mentioned                            Stay safe  di amp  da
# 4   Neutral  Not Mentioned    This is what passes for leadership in our co...
# 5   Neutral  Not Mentioned  The Multisystem Inflammary SyndromeChildren MI...
# 6   Neutral  Not Mentioned
# 7  Negative  Not Mentioned   Well lets qualify that would anyone of any pa...
# 8  Positive  Not Mentioned  Most countries without  ability  make Vaccines...
# 9   Neutral  Not Mentioned  DNA  zooms up charts in 1st week hear vaccines...
#
#      MENTIONED_BRAND  YYYY-MM
# 0      Not Mentioned  2020-08
# 1  CoronaVac - China  2020-08
# 2      Not Mentioned  2020-08
# 3      Not Mentioned  2020-08
# 4      Not Mentioned  2020-08
# 5      Not Mentioned  2020-08
# 6      Not Mentioned  2020-08
# 7      Not Mentioned  2020-08
# 8      Not Mentioned  2020-08
# 9      Not Mentioned  2020-08
#
# [10 rows x 21 columns]

# %%
# store cleaned tweets in a list
tweets_cleaned = data_file["TEXT_CLEANED"]
tweets_cleaned
# Out:
# 0         Australia  Manufacture Covid19 Vaccine  give i...
# 1         CoronavirusVaccine CoronaVaccine CovidVaccine ...
# 2         Deaths due  COVID19 in Affected Countries\nRea...
# 3                                   Stay safe  di amp  da
# 4           This is what passes for leadership in our co...
#                                 ...
# 156485    Very good news about  efficacy of  JampJ vacci...
# 156486    s Foreign Minister Wang Yi has also said that ...
# 156487    Super excited  have received my second covidva...
# 156488    Repeat after me Canadians are polite y wont lo...
# 156489    Instead of postponing psl why not vaccinate al...
# Name: TEXT_CLEANED, Length: 156490, dtype: object

# %%
# Split and lower-case words in all tweets by comibining .lower() and .split()  methods in a list comprehension
words_in_tweet = [tweet.lower().split() for tweet in tweets_cleaned]
words_in_tweet[:2]
# Out:
# [['australia',
#   'manufacture',
#   'covid19',
#   'vaccine',
#   'give',
#   'it',
#   'citizens',
#   'for',
#   'free',
#   'of',
#   'cost',
#   'afp',
#   'quotes',
#   'prime',
#   'minister',
#   'covidvaccine'],
#  ['coronavirusvaccine',
#   'coronavaccine',
#   'covidvaccine',
#   'australia',
#   'is',
#   'doing',
#   'very',
#   'good']]

# %%
# List of all words across tweets
all_words_no_urls = list(itertools.chain(*words_in_tweet))

# %%
# Create counter
counts_no_urls = collections.Counter(all_words_no_urls)

# %%
counts_no_urls.most_common(15)
# Out:
# [('covidvaccine', 79754),
#  ('of', 44375),
#  ('a', 41363),
#  ('in', 37379),
#  ('vaccine', 36676),
#  ('for', 31569),
#  ('is', 30781),
#  ('covid19', 29149),
#  ('i', 22914),
#  ('you', 20865),
#  ('this', 18800),
#  ('my', 18549),
#  ('on', 17801),
#  ('are', 17332),
#  ('have', 15066)]

# %%
stop_words = set(stopwords.words('english'))

# %%
# View a few words from the set
list(stop_words)[0:10]
# Out:
# ['by',
#  "you're",
#  "couldn't",
#  'y',
#  'yourself',
#  'a',
#  'is',
#  "isn't",
#  'shouldn',
#  'll']

# %%
# Remove all of the stop words in each tweet
for all_words in words_in_tweet:
    for word in all_words:
        # Remove stop words from each tweet list of words
        tweets_nsw = [[word for word in tweet_words if not word in stop_words]
                      for tweet_words in words_in_tweet]

tweets_nsw[0]

# %%
# Flatten list & create counter to return the most commonly used words and their frequencies. 
all_words_nsw = list(itertools.chain(*tweets_nsw))

counts_nsw = collections.Counter(all_words_nsw)

counts_nsw.most_common(15)

# %%
# Create Dataframe & plot the word frequencies without the stop words.
clean_tweets_nsw = pd.DataFrame(counts_nsw.most_common(15),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_nsw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="purple")

ax.set_title("Common Words Found in Tweets (Without Stop Words)")

plt.show()
